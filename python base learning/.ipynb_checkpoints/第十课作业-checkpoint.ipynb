# %%
from random import *

# %%
win = 0
for i in range(10000):
    selectlist = ["山羊","车","山羊"]
    usrchoice = choice(selectlist)
    selectlist.remove("山羊")
    if userchoice == "车":
        win = win + 1

for i in range(10000):
    selectlist = ["山羊","车","山羊"]
    usrchoice = choice(selectlist)
    selectlist.remove("山羊")
    if userchoice != "车":
        win = win + 1

print(win/20000)
# Out:
# 0.5

# %%
userchoice
selectlist
# Out:
# ['车', '山羊']

# %%
eval("1+(1)")
# Out:
# 2

# %%
import collections
from itertools import *
number = [2,2,2,9]
def point24(number):
    
            return ( "({0}{4}{1}){5}{2}{6}{3}".format(*number,*op),
             "(({0}{4}{1}){5}{2}){6}{3}".format(*number,*op),
             "{0}{4}({1}{5}{2}){6}{3}".format(*number,*op),
             "{0}{4}(({1}{5}{2}){6}{3})".format(*number,*op),
             "({0}{4}{1}){5}({2}{6}{3})".format(*number,*op) for op in product("+-*/",repeat=3))
# Out:
#   File "<ipython-input-8-644b109a8f23>", line 10
#     "({0}{4}{1}){5}({2}{6}{3})".format(*number,*op) for op in product("+-*/",repeat=3))
#                                                       ^
# SyntaxError: invalid syntax

# %%
point24(number)
# Out:
# (2+2)+2+9
# ((2+2)+2)+9
# 2+(2+2)+9
# 2+((2+2)+9)
# (2+2)+(2+9)
# (2+2)+2-9
# ((2+2)+2)-9
# 2+(2+2)-9
# 2+((2+2)-9)
# (2+2)+(2-9)
# (2+2)+2*9
# ((2+2)+2)*9
# 2+(2+2)*9
# 2+((2+2)*9)
# (2+2)+(2*9)
# (2+2)+2/9
# ((2+2)+2)/9
# 2+(2+2)/9
# 2+((2+2)/9)
# (2+2)+(2/9)
# (2+2)-2+9
# ((2+2)-2)+9
# 2+(2-2)+9
# 2+((2-2)+9)
# (2+2)-(2+9)
# (2+2)-2-9
# ((2+2)-2)-9
# 2+(2-2)-9
# 2+((2-2)-9)
# (2+2)-(2-9)
# (2+2)-2*9
# ((2+2)-2)*9
# 2+(2-2)*9
# 2+((2-2)*9)
# (2+2)-(2*9)
# (2+2)-2/9
# ((2+2)-2)/9
# 2+(2-2)/9
# 2+((2-2)/9)
# (2+2)-(2/9)
# (2+2)*2+9
# ((2+2)*2)+9
# 2+(2*2)+9
# 2+((2*2)+9)
# (2+2)*(2+9)
# (2+2)*2-9
# ((2+2)*2)-9
# 2+(2*2)-9
# 2+((2*2)-9)
# (2+2)*(2-9)
# (2+2)*2*9
# ((2+2)*2)*9
# 2+(2*2)*9
# 2+((2*2)*9)
# (2+2)*(2*9)
# (2+2)*2/9
# ((2+2)*2)/9
# 2+(2*2)/9
# 2+((2*2)/9)
# (2+2)*(2/9)
# (2+2)/2+9
# ((2+2)/2)+9
# 2+(2/2)+9
# 2+((2/2)+9)
# (2+2)/(2+9)
# (2+2)/2-9
# ((2+2)/2)-9
# 2+(2/2)-9
# 2+((2/2)-9)
# (2+2)/(2-9)
# (2+2)/2*9
# ((2+2)/2)*9
# 2+(2/2)*9
# 2+((2/2)*9)
# (2+2)/(2*9)
# ...
