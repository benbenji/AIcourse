# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10,10,1000)
y = 1/(1 + np.exp(-x))
y1 = (np.exp(x) - np.exp(-x))/(np.exp(x) + np.exp(-x))
with plt.style.context("seaborn-ticks"):
    plt.plot(x,y1,"g-",linewidth=2,label="Curve 1")
    plt.plot(x,y,"r:",linewidth=3,label="Curve 2")
    plt.title("Two curves")
    plt.xlim(-10,10)
    plt.ylim(-1.5,1.5)
    plt.xticks(np.arange(-10,10,step=1),fontsize=15)
    plt.legend()
    plt.savefig("Two_curves.png")

# %%
x = np.linspace(-10,10,40)
y = 1/(1 + np.exp(-x))
y1 = (np.exp(x) - np.exp(-x))/(np.exp(x) + np.exp(-x))
size = np.random.rand(40)
plt.scatter(x,y,c=y,cmap="Blues",s=100 * size,alpha=0.8)
plt.colorbar()
plt.scatter(x,y1,c=y,cmap="Reds",s=100 * size,alpha=0.3)
plt.colorbar()

# %%
x = np.linspace(0,10,40)
y = 1/(1 + np.exp(-x))
y1 = (np.exp(x) - np.exp(-x))/(np.exp(x) + np.exp(-x))
plt.bar(x, y, align="center",color='yellow', edgecolor='red')
plt.bar(x, y1, bottom=y,edgecolor='red')
# Out:
# <BarContainer object of 40 artists>

# %%
plt.barh(x, y, align="center",color='red',height=0.125)
plt.barh(x+0.125, y1,height=0.125,color='blue')
# Out:
# <BarContainer object of 40 artists>

# %%
plt.bar(x, y, align="center",color='red',width=0.125)
plt.bar(x+0.125, y1, width=0.125,color='blue')
plt.ylim(0,1.5)
# Out:
# (0, 1.5)

# %%
x = np.linspace(-10,10,1000)
y = 1/(1 + np.exp(-x))
y1 = (np.exp(x) - np.exp(-x))/(np.exp(x) + np.exp(-x))
y2 = np.sin(x)
y3 = np.cos(x)

# %%
plt.subplot(221)
plt.plot(x,y,'o-',markerfacecolor="r", markersize=1)
plt.subplot(222)
plt.plot(x,y1,"r--")
plt.subplot(223)
plt.plot(x,y2,"b+")
plt.subplot(224)
plt.plot(x,y3,"g-")

# %%
mu, sigma = 100, 5
x = mu + sigma * np.random.randn(10000)
plt.hist(x, bins=50, #区间
         facecolor='g', alpha=0.75)
# Out:
# (array([  1.,   0.,   1.,   3.,   0.,   3.,   2.,   8.,  25.,  19.,  49.,
#          75.,  84., 122., 180., 229., 262., 347., 405., 530., 541., 617.,
#         672., 669., 702., 659., 658., 573., 532., 478., 400., 306., 234.,
#         173., 154.,  94.,  66.,  47.,  36.,  16.,  11.,   6.,   5.,   4.,
#           1.,   0.,   0.,   0.,   0.,   1.]),
#  array([ 78.98794864,  79.85711461,  80.72628057,  81.59544654,
#          82.4646125 ,  83.33377847,  84.20294443,  85.0721104 ,
#          85.94127636,  86.81044233,  87.67960829,  88.54877426,
#          89.41794022,  90.28710619,  91.15627215,  92.02543812,
#          92.89460408,  93.76377005,  94.63293601,  95.50210198,
#          96.37126794,  97.24043391,  98.10959987,  98.97876584,
#          99.8479318 , 100.71709777, 101.58626373, 102.4554297 ,
#         103.32459566, 104.19376163, 105.06292759, 105.93209356,
#         106.80125952, 107.67042549, 108.53959145, 109.40875742,
#         110.27792338, 111.14708935, 112.01625531, 112.88542128,
#         113.75458724, 114.62375321, 115.49291917, 116.36208514,
#         117.2312511 , 118.10041707, 118.96958303, 119.838749  ,
#         120.70791496, 121.57708093, 122.44624689]),
#  <a list of 50 Patch objects>)

# %%
from scipy.stats import norm
_, bins, __ = plt.hist(x,50,density=True) #获取
y = norm.pdf(bins,mu,sigma) #返回一个区间的概率密度
plt.plot(bins,y)

# %%
bins
# Out:
# array([ 78.98794864,  79.85711461,  80.72628057,  81.59544654,
#         82.4646125 ,  83.33377847,  84.20294443,  85.0721104 ,
#         85.94127636,  86.81044233,  87.67960829,  88.54877426,
#         89.41794022,  90.28710619,  91.15627215,  92.02543812,
#         92.89460408,  93.76377005,  94.63293601,  95.50210198,
#         96.37126794,  97.24043391,  98.10959987,  98.97876584,
#         99.8479318 , 100.71709777, 101.58626373, 102.4554297 ,
#        103.32459566, 104.19376163, 105.06292759, 105.93209356,
#        106.80125952, 107.67042549, 108.53959145, 109.40875742,
#        110.27792338, 111.14708935, 112.01625531, 112.88542128,
#        113.75458724, 114.62375321, 115.49291917, 116.36208514,
#        117.2312511 , 118.10041707, 118.96958303, 119.838749  ,
#        120.70791496, 121.57708093, 122.44624689])

# %%
norm.pdf([0.5,0,0.6])
# Out:
# array([0.35206533, 0.39894228, 0.3332246 ])

# %%
_, bins, __ = plt.hist(x,50,density=True, cumulative=True) 
y = norm.cdf(bins,mu,sigma)
plt.plot(bins,y,'r--',lw=3)

# %%
from mpl_toolkits import mplot3d
zdata = np.linspace(0,15,10)
xdata = np.sin(np.linspace(0, 2*np.pi, 100))
ydata = np.cos(np.linspace(0, 2*np.pi, 100))
# ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap="spring")

# %%
X,Z= np.meshgrid(xdata,zdata)

# %%
Y,Z= np.meshgrid(ydata,zdata)

# %%
ax = plt.axes(projection="3d")
# ax.scatter3D(X.flatten(), Y.flatten(), Z.flatten())
ax.scatter3D(X, Y, Z)
